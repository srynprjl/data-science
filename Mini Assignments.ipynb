# %% [markdown]
# ## Mini Assignment 1

# %% [markdown]
# #### 1. Print your full name

# %%
print("Shreyan Parajuli");
# Out:
# Shreyan Parajuli

# %% [markdown]
# ####  2. Print your fav quote

# %%
print("If at first you don’t succeed, try, try again")
# Out:
# If at first you don’t succeed, try, try again

# %% [markdown]
# #### 3. Print a sentence in a multiple line using \n

# %%
print("This is the first line \nThis is the second line")
# Out:
# This is the first line
# This is the second line

# %% [markdown]
# ### Mini Assignment 2

# %%
name="Shreyan Parajuli"
age=19
country="Nepal"

# %%
print(f" My name is {name} and I am {age} years old. \nI live in country {country}")
# Out:
#  My name is Shreyan Parajuli and I am 19 years old.
# I live in country Nepal

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(country))
# Out:
# <class 'str'>

# %% [markdown]
# ## Mini Assignment 3

# %%
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))

print(f"Sum: {a+b} , Difference: {a-b}, Product: {a*b}")

print(f"is Divisible: {a % b == 0}")

# if a%b == 0:
#     print("it is Divisible")

print(f"is both even? : {a%2 == 0 and b%0 ==0}")
# Out:
# Enter a number:  2.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a = int(input("Enter a number: "))
#       2 b = int(input("Enter another number: "))
#       4 print(f"Sum: {a+b} , Difference: {a-b}, Product: {a*b}")
#
# ValueError: invalid literal for int() with base 10: '2.0'

# %% [markdown]
# ## Mini Assignment 5

# %%
a = int(input("Enter a number: "))
if(a > 0):
    print(f"{a} is positive")
elif (a < 0):
    print(f"{a} is negative")
else:
    print("Zero");
# Out:
# Enter a number:  0
# Zero

# %%
a = int(input("Enter your marks: "))
if(a >= 90 and a <=100):
    print("A")
elif(a >= 70 and a < 90):
    print("B")
elif(a >= 40 and a < 70):
    print("C")
elif (a >=0 and a < 40):
    print("F")
# Out:
# Enter your marks:  40
# C

# %%
a = int(input("Number: "))
if( a % 2 == 0 ):
    print("Even")
else:
    print("Odd")
# Out:
# Number:  2
# Odd
